# %% [markdown]
# ### Prompts analysis

# %%
import pandas as pd

# %%
tasks = {
    "asthma_classification": "Obesity Co-Morbidity (Asthma)",
    "cohort_alcohol_abuse_classification": "Cohort Alcohol Abuse",
    "cad_classification": "Obesity Co-Morbidity (CAD)",
    "cohort_drug_abuse_classification": "Cohort Drug Abuse",
    "cohort_english_classification": "Cohort English",
    "cohort_make_decisions_classification": "Cohort Make Decisions",
    "cohort_abdominal_classification": "Cohort Abdominal",
    "diabetes_mellitus_classification": "Obesity Co-Morbidity (Diabetes Mellitus)",
    "obesity_classification": "Obesity",
}

ext_tasks = [
    "drug_extraction",
    "medication_extraction",
    "concept_treatment_extraction",
    "concept_problem_extraction",
    "concept_test_extraction",
    "risk_factor_cad_extraction",
]


inst = pd.read_csv("../instructions/instructions_from_experts.csv")

# %%
import pandas as pd
import textstat

# Function to calculate readability score for a given text
def calculate_readability(text):
    try:
        return textstat.flesch_reading_ease(text)
    except Exception as e:
        print(f"Error calculating readability: {e}")
        return None

# Function to process each column and calculate readability scores
def process_columns(df):
    for column in df.columns:
        if df[column].dtype == 'object':  # Check if column contains text data
            print(f"Processing column '{column}'")
            readability_scores = df[column].apply(calculate_readability)
            df[f"{column}_readability_score"] = readability_scores
            print(f"Readability scores for column '{column}':")
            print(readability_scores)
            print()

# Read CSV into a pandas DataFrame
def main(csv_file):
    try:
        df = pd.read_csv(csv_file)
        process_columns(df)
        # Optionally, save the modified DataFrame back to CSV
        df.to_csv("output_with_readability_scores.csv", index=False)
    except Exception as e:
        print(f"Error reading or processing CSV file: {e}")

# Example usage
if __name__ == "__main__":
    csv_file = "../instructions/instructions_from_experts.csv"  # Replace with your CSV file path
    main(csv_file)
# Out:
# Processing column 'Name'
# Readability scores for column 'Name':
# 0    -132.59
# 1    -132.59
# 2    -132.59
# 3    -132.59
# 4    -132.59
# 5    -132.59
# 6    -132.59
# 7    -132.59
# 8    -132.59
# 9    -132.59
# 10   -132.59
# 11   -132.59
# Name: Name, dtype: float64
#
# Processing column 'Cohort Drug Abuse Classification
# Input: medical notes of a single patient (assume the notes are given above the instruction.)
#
# Given a corpus of longitudinal medical records of a single patient, your aim is to have the model classify if the patient meets or does not meet the definition of drug abuse.
#
# Please write your instruction in such a way that the model will include one of "Yes" or "No" in the response.'
# Readability scores for column 'Cohort Drug Abuse Classification
# Input: medical notes of a single patient (assume the notes are given above the instruction.)
#
# Given a corpus of longitudinal medical records of a single patient, your aim is to have the model classify if the patient meets or does not meet the definition of drug abuse.
#
# Please write your instruction in such a way that the model will include one of "Yes" or "No" in the response.':
# 0     65.42
# 1     31.38
# 2     56.76
# 3     54.56
# 4     83.66
# 5     40.69
# 6     27.15
# 7     67.76
# 8     57.95
# 9     64.71
# 10    61.16
# 11    60.35
# Name: Cohort Drug Abuse Classification\nInput: medical notes of a single patient (assume the notes are given above the instruction.)\n\nGiven a corpus of longitudinal medical records of a single patient, your aim is to have the model classify if the patient meets or does not meet the definition of drug abuse.\n\nPlease write your instruction in such a way that the model will include one of "Yes" or "No" in the response., dtype: float64
#
# Processing column 'Cohort Alcohol Abuse Classification
# Input: medical notes of a single patient (assume the notes are given above the instruction.)
#
# Given a corpus of longitudinal medical records of a single patient, your aim is to have the model classify if the patient meets or does not meet the definition of alcohol abuse.
#
# Please write your instruction in such a way that the model will include one of "Yes" or "No" in the response.'
# Readability scores for column 'Cohort Alcohol Abuse Classification
# Input: medical notes of a single patient (assume the notes are given above the instruction.)
#
# Given a corpus of longitudinal medical records of a single patient, your aim is to have the model classify if the patient meets or does not meet the definition of alcohol abuse.
#
# Please write your instruction in such a way that the model will include one of "Yes" or "No" in the response.':
# 0     57.61
# 1     21.06
# 2     66.23
# 3     47.12
# 4     73.17
# 5     30.91
# 6     66.07
# 7     58.79
# 8     62.01
# 9     56.25
# 10    49.65
# 11    53.51
# Name: Cohort Alcohol Abuse Classification\nInput: medical notes of a single patient (assume the notes are given above the instruction.)\n\nGiven a corpus of longitudinal medical records of a single patient, your aim is to have the model classify if the patient meets or does not meet the definition of alcohol abuse.\n\nPlease write your instruction in such a way that the model will include one of "Yes" or "No" in the response., dtype: float64
#
# Processing column 'Cohort English Classification
# Input: medical notes of a single patient (assume the notes are given above the instruction.)
#
# Given a corpus of longitudinal medical records of a single patient, your aim is to have the model classify if the patient meets or does not meet the definition of english speaker.
#
# Please write your instruction in such a way that the model will include one of "Yes" or "No" in the response.'
# Readability scores for column 'Cohort English Classification
# Input: medical notes of a single patient (assume the notes are given above the instruction.)
#
# Given a corpus of longitudinal medical records of a single patient, your aim is to have the model classify if the patient meets or does not meet the definition of english speaker.
#
# Please write your instruction in such a way that the model will include one of "Yes" or "No" in the response.':
# 0     49.15
# 1     31.04
# 2     74.69
# 3     57.61
# 4     79.26
# 5     43.56
# 6     58.62
# 7     61.33
# 8     58.96
# 9     65.73
# 10    39.67
# 11    69.62
# Name: Cohort English Classification\nInput: medical notes of a single patient (assume the notes are given above the instruction.)\n\nGiven a corpus of longitudinal medical records of a single patient, your aim is to have the model classify if the patient meets or does not meet the definition of english speaker.\n\nPlease write your instruction in such a way that the model will include one of "Yes" or "No" in the response., dtype: float64
#
# Processing column 'Cohort Makes-Decision Classification
# Input: medical notes of a single patient (assume the notes are given above the instruction.)
#
# Given a corpus of longitudinal medical records of a single patient, your aim is to have the model classify if the patient meets or does not meet the definition of "patient make their own medical decisions".
#
# Please write your instruction in such a way that the model will include one of "Yes" or "No" in the response.'
# Readability scores for column 'Cohort Makes-Decision Classification
# Input: medical notes of a single patient (assume the notes are given above the instruction.)
#
# Given a corpus of longitudinal medical records of a single patient, your aim is to have the model classify if the patient meets or does not meet the definition of "patient make their own medical decisions".
#
# Please write your instruction in such a way that the model will include one of "Yes" or "No" in the response.':
# 0     50.16
# 1     41.53
# 2     45.76
# 3     25.46
# 4     70.80
# 5     22.95
# 6     57.27
# 7     60.31
# 8     65.39
# 9     34.94
# 10    30.70
# 11    56.59
# Name: Cohort Makes-Decision Classification\nInput: medical notes of a single patient (assume the notes are given above the instruction.)\n\nGiven a corpus of longitudinal medical records of a single patient, your aim is to have the model classify if the patient meets or does not meet the definition of "patient make their own medical decisions".\n\nPlease write your instruction in such a way that the model will include one of "Yes" or "No" in the response., dtype: float64
#
# Processing column 'Cohort Abdominal Classification
# Input: medical notes of a single patient (assume the notes are given above the instruction.)
#
# Given a corpus of longitudinal medical records of a single patient, your aim is to have the model classify if the patient does or does not have history of intra-abdominal surgery, small or large intestine resection, or small bowel obstruction.
#
# Please write your instruction in such a way that the model will include one of "Yes" or "No" in the response.'
# Readability scores for column 'Cohort Abdominal Classification
# Input: medical notes of a single patient (assume the notes are given above the instruction.)
#
# Given a corpus of longitudinal medical records of a single patient, your aim is to have the model classify if the patient does or does not have history of intra-abdominal surgery, small or large intestine resection, or small bowel obstruction.
#
# Please write your instruction in such a way that the model will include one of "Yes" or "No" in the response.':
# 0     21.06
# 1     33.54
# 2     52.19
# 3     18.36
# 4     67.45
# 5     30.70
# 6     37.30
# 7     46.78
# 8     41.37
# 9     42.72
# 10    42.72
# 11    25.63
# Name: Cohort Abdominal Classification\nInput: medical notes of a single patient (assume the notes are given above the instruction.)\n\nGiven a corpus of longitudinal medical records of a single patient, your aim is to have the model classify if the patient does or does not have history of intra-abdominal surgery, small or large intestine resection, or small bowel obstruction.\n\nPlease write your instruction in such a way that the model will include one of "Yes" or "No" in the response., dtype: float64
#
# Processing column 'MIMIC Mortality Prediction
# Input: medical notes of a single patient (assume the notes are given above the instruction.)
#
# Given some notes from a patient encounter, your aim is to have the model classify whether or not the patient will die during the course of a stay in the hospital given notes from the first 48 hours.
#
# Please write your instruction in such a way that the model will include one of "Yes" or "No" in the response.'
# Readability scores for column 'MIMIC Mortality Prediction
# Input: medical notes of a single patient (assume the notes are given above the instruction.)
#
# Given some notes from a patient encounter, your aim is to have the model classify whether or not the patient will die during the course of a stay in the hospital given notes from the first 48 hours.
#
# Please write your instruction in such a way that the model will include one of "Yes" or "No" in the response.':
# 0     59.98
# 1     27.49
# 2     89.58
# 3     41.37
# 4     74.02
# 5     42.04
# 6     42.88
# 7     87.05
# 8     65.39
# 9     80.11
# 10    54.05
# 11    65.73
# Name: MIMIC Mortality Prediction\nInput: medical notes of a single patient (assume the notes are given above the instruction.)\n\nGiven some notes from a patient encounter, your aim is to have the model classify whether or not the patient will die during the course of a stay in the hospital given notes from the first 48 hours.\n\nPlease write your instruction in such a way that the model will include one of "Yes" or "No" in the response., dtype: float64
#
# Processing column 'Obesity Classification
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a patient discharge note, your aim is to have the model classify the patient's obesity status into one of the two categories: Present and Absent
#
# Here is the detailed definition of the categories:
#
# Present: the patient has/had the disease.
# Absent: the patient does/did not have the disease.
# Please write your instruction in such a way that the model will include one of "Present", "Absent" in the response.'
# Readability scores for column 'Obesity Classification
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a patient discharge note, your aim is to have the model classify the patient's obesity status into one of the two categories: Present and Absent
#
# Here is the detailed definition of the categories:
#
# Present: the patient has/had the disease.
# Absent: the patient does/did not have the disease.
# Please write your instruction in such a way that the model will include one of "Present", "Absent" in the response.':
# 0     35.10
# 1     49.99
# 2     65.01
# 3     52.56
# 4     60.01
# 5     38.66
# 6     37.64
# 7     35.28
# 8     68.60
# 9     39.00
# 10    43.73
# 11    53.21
# Name: Obesity Classification\nInput: the discharge note of a single patient (assume the notes are given above the instruction.)\nGiven a patient discharge note, your aim is to have the model classify the patient's obesity status into one of the two categories: Present and Absent\n\nHere is the detailed definition of the categories:\n\nPresent: the patient has/had the disease.\nAbsent: the patient does/did not have the disease.\nPlease write your instruction in such a way that the model will include one of "Present", "Absent" in the response., dtype: float64
#
# Processing column 'Obesity Co-Morbidity Classification (Diabetes Mellitus)
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a patient discharge note, your aim is to have the model classify the patient's status of diabetes mellitus (DM) - a frequently occurring obesity co-morbidity - into one of the two categories: Present and Absent. Here is the detailed definition of the categories:
#
# Present: the patient has/had the co-morbidity.
# Absent: the patient does/did not have the co-morbidity.
# Please write your instruction in such a way that the model will include one of "Present" or "Absent" in the response.'
# Readability scores for column 'Obesity Co-Morbidity Classification (Diabetes Mellitus)
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a patient discharge note, your aim is to have the model classify the patient's status of diabetes mellitus (DM) - a frequently occurring obesity co-morbidity - into one of the two categories: Present and Absent. Here is the detailed definition of the categories:
#
# Present: the patient has/had the co-morbidity.
# Absent: the patient does/did not have the co-morbidity.
# Please write your instruction in such a way that the model will include one of "Present" or "Absent" in the response.':
# 0     17.51
# 1     11.08
# 2     41.36
# 3     50.84
# 4     30.87
# 5     35.31
# 6     33.58
# 7     47.49
# 8     23.43
# 9     47.79
# 10    31.21
# 11    40.69
# Name: Obesity Co-Morbidity Classification (Diabetes Mellitus)\nInput: the discharge note of a single patient (assume the notes are given above the instruction.)\nGiven a patient discharge note, your aim is to have the model classify the patient's status of diabetes mellitus (DM) - a frequently occurring obesity co-morbidity - into one of the two categories: Present and Absent. Here is the detailed definition of the categories:\n\nPresent: the patient has/had the co-morbidity.\nAbsent: the patient does/did not have the co-morbidity.\nPlease write your instruction in such a way that the model will include one of "Present" or "Absent" in the response., dtype: float64
#
# Processing column 'Obesity Co-Morbidity Classification (Asthma)
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a patient discharge note, your aim is to have the model classify the patient's status of Asthma - a frequently occurring obesity co-morbidity- into one of the two categories: Present and Absent. Here is the detailed definition of the categories:
#
# Present: the patient has/had the co-morbidity.
# Absent: the patient does/did not have the co-morbidity.
# Please write your instruction in such a way that the model will include one of "Present" or "Absent" in the response.'
# Readability scores for column 'Obesity Co-Morbidity Classification (Asthma)
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a patient discharge note, your aim is to have the model classify the patient's status of Asthma - a frequently occurring obesity co-morbidity- into one of the two categories: Present and Absent. Here is the detailed definition of the categories:
#
# Present: the patient has/had the co-morbidity.
# Absent: the patient does/did not have the co-morbidity.
# Please write your instruction in such a way that the model will include one of "Present" or "Absent" in the response.':
# 0     30.91
# 1     22.08
# 2     50.02
# 3     61.02
# 4     31.58
# 5     45.80
# 6     45.46
# 7     58.99
# 8     66.03
# 9     56.76
# 10    40.69
# 11    54.73
# Name: Obesity Co-Morbidity Classification (Asthma)\nInput: the discharge note of a single patient (assume the notes are given above the instruction.)\nGiven a patient discharge note, your aim is to have the model classify the patient's status of Asthma - a frequently occurring obesity co-morbidity- into one of the two categories: Present and Absent. Here is the detailed definition of the categories:\n\nPresent: the patient has/had the co-morbidity.\nAbsent: the patient does/did not have the co-morbidity.\nPlease write your instruction in such a way that the model will include one of "Present" or "Absent" in the response., dtype: float64
#
# Processing column 'Obesity Co-Morbidity Classification (CAD)
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a patient discharge note, your aim is to have the model classify the patient's status of Coronary artery disease (CAD) - a frequently occurring obesity co-morbidity - into one of the two categories: Present and Absent. Here is the detailed definition of the categories:
# Present: the patient has/had the co-morbidity.
# Absent: the patient does/did not have the co-morbidity.
#
# Please write your instruction in such a way that the model will include one of "Present" or "Absent" in the response.'
# Readability scores for column 'Obesity Co-Morbidity Classification (CAD)
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a patient discharge note, your aim is to have the model classify the patient's status of Coronary artery disease (CAD) - a frequently occurring obesity co-morbidity - into one of the two categories: Present and Absent. Here is the detailed definition of the categories:
# Present: the patient has/had the co-morbidity.
# Absent: the patient does/did not have the co-morbidity.
#
# Please write your instruction in such a way that the model will include one of "Present" or "Absent" in the response.':
# 0     40.01
# 1     27.49
# 2     49.52
# 3     66.44
# 4     39.03
# 5     42.75
# 6     37.30
# 7     55.24
# 8     64.00
# 9     60.65
# 10    39.67
# 11    52.70
# Name: Obesity Co-Morbidity Classification (CAD)\nInput: the discharge note of a single patient (assume the notes are given above the instruction.)\nGiven a patient discharge note, your aim is to have the model classify the patient's status of Coronary artery disease (CAD) - a frequently occurring obesity co-morbidity - into one of the two categories: Present and Absent. Here is the detailed definition of the categories:\nPresent: the patient has/had the co-morbidity.\nAbsent: the patient does/did not have the co-morbidity.\n\nPlease write your instruction in such a way that the model will include one of "Present" or "Absent" in the response., dtype: float64
#
# Processing column 'Phenotype Classification (Queried)
# Input: some patient notes of a single patient (assume the notes are already given above the instruction.)
#
# Given some patient notes, your aim is to have the model classify whether a particular phenotype (e.g. acute and unspecified renal failure) is observed in the note. In your instruction, refer to this phenotype using the placeholder '{phenotype}'.
#
# Please write your instruction in such a way that the model will include one of "Yes" or "No" in the response.'
# Readability scores for column 'Phenotype Classification (Queried)
# Input: some patient notes of a single patient (assume the notes are already given above the instruction.)
#
# Given some patient notes, your aim is to have the model classify whether a particular phenotype (e.g. acute and unspecified renal failure) is observed in the note. In your instruction, refer to this phenotype using the placeholder '{phenotype}'.
#
# Please write your instruction in such a way that the model will include one of "Yes" or "No" in the response.':
# 0     47.12
# 1     17.00
# 2     75.71
# 3     58.62
# 4     68.77
# 5     37.00
# 6     38.32
# 7     79.77
# 8     67.08
# 9     83.66
# 10    62.68
# 11    62.17
# Name: Phenotype Classification (Queried)\nInput: some patient notes of a single patient (assume the notes are already given above the instruction.)\n\nGiven some patient notes, your aim is to have the model classify whether a particular phenotype (e.g. acute and unspecified renal failure) is observed in the note. In your instruction, refer to this phenotype using the placeholder '{phenotype}'. \n\nPlease write your instruction in such a way that the model will include one of "Yes" or "No" in the response., dtype: float64
#
# Processing column 'Readmission Classification
# Input: some patient notes of a single patient (assume the notes are given above the instruction.)
#
# Given some notes from a patient encounter, your aim is to have the model classify whether or not the patient will be readmitted to the hospital within 30 days.
#
# Please write your instruction in such a way that the model will include one of "Yes" or "No" in the response.'
# Readability scores for column 'Readmission Classification
# Input: some patient notes of a single patient (assume the notes are given above the instruction.)
#
# Given some notes from a patient encounter, your aim is to have the model classify whether or not the patient will be readmitted to the hospital within 30 days.
#
# Please write your instruction in such a way that the model will include one of "Yes" or "No" in the response.':
# 0     37.94
# 1     21.06
# 2     82.14
# 3     36.29
# 4     66.07
# 5     38.66
# 6     59.64
# 7     75.71
# 8     57.95
# 9     72.66
# 10    59.13
# 11    73.00
# Name: Readmission Classification\nInput: some patient notes of a single patient (assume the notes are given above the instruction.)\n\nGiven some notes from a patient encounter, your aim is to have the model classify whether or not the patient will be readmitted to the hospital within 30 days.\n\nPlease write your instruction in such a way that the model will include one of "Yes" or "No" in the response., dtype: float64
#
# Processing column 'Assertion Classification (Queried)
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a discharge summary note of a patient and a medical treatment mentioned in the note, your aim is to have the model classify whether the treatment mentioned is: Present, Conditional, Absent, Possible, Hypothetical, and Associated_with_someone_else. In your instruction, refer to the medical treatment using the placeholder '{treatment}'.
# Here is the detailed definition of the categories:
# Present:  problems associated with the patient can be present. This is the default category for medical problems and it contains that do not fit the definition of any of the other assertion category.
# Conditional: the mention of the medical problem asserts that the patient experiences the problem only under certain conditions. Allergies can fall into this category.
# Absent: the note asserts that the problem does not exist in the patient. This category also includes mentions where it is stated that the patient HAD a problem, but no longer does.
# Possible: the note asserts that the patient may have a problem, but uncertainty is expressed in the note. Possible takes precedence over absent, so terms like “probably not” or “unlikely” categorize problems as being possible just as “probably” and “likely” do.
# Hypothetical: medical problems that the note asserts the patient may develop.
# Associated_with_someone_else: the mention of the medical problem is associated with someone who is not the patient.
#
# Please write your instruction in such a way that the model will include one of "Present", "Conditional", "Absent", "Possible", "Hypothetical", or "Associated_with_someone_else" in the response. Don't simply copy and paste the provided label descriptions.'
# Readability scores for column 'Assertion Classification (Queried)
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a discharge summary note of a patient and a medical treatment mentioned in the note, your aim is to have the model classify whether the treatment mentioned is: Present, Conditional, Absent, Possible, Hypothetical, and Associated_with_someone_else. In your instruction, refer to the medical treatment using the placeholder '{treatment}'.
# Here is the detailed definition of the categories:
# Present:  problems associated with the patient can be present. This is the default category for medical problems and it contains that do not fit the definition of any of the other assertion category.
# Conditional: the mention of the medical problem asserts that the patient experiences the problem only under certain conditions. Allergies can fall into this category.
# Absent: the note asserts that the problem does not exist in the patient. This category also includes mentions where it is stated that the patient HAD a problem, but no longer does.
# Possible: the note asserts that the patient may have a problem, but uncertainty is expressed in the note. Possible takes precedence over absent, so terms like “probably not” or “unlikely” categorize problems as being possible just as “probably” and “likely” do.
# Hypothetical: medical problems that the note asserts the patient may develop.
# Associated_with_someone_else: the mention of the medical problem is associated with someone who is not the patient.
#
# Please write your instruction in such a way that the model will include one of "Present", "Conditional", "Absent", "Possible", "Hypothetical", or "Associated_with_someone_else" in the response. Don't simply copy and paste the provided label descriptions.':
# 0      0.72
# 1     -2.80
# 2     35.37
# 3     42.11
# 4     39.94
# 5     44.85
# 6     32.94
# 7     37.81
# 8     37.34
# 9     42.07
# 10    14.46
# 11    18.86
# Name: Assertion Classification (Queried)\nInput: the discharge note of a single patient (assume the notes are given above the instruction.)\nGiven a discharge summary note of a patient and a medical treatment mentioned in the note, your aim is to have the model classify whether the treatment mentioned is: Present, Conditional, Absent, Possible, Hypothetical, and Associated_with_someone_else. In your instruction, refer to the medical treatment using the placeholder '{treatment}'.\nHere is the detailed definition of the categories:\nPresent:  problems associated with the patient can be present. This is the default category for medical problems and it contains that do not fit the definition of any of the other assertion category.\nConditional: the mention of the medical problem asserts that the patient experiences the problem only under certain conditions. Allergies can fall into this category.\nAbsent: the note asserts that the problem does not exist in the patient. This category also includes mentions where it is stated that the patient HAD a problem, but no longer does. \nPossible: the note asserts that the patient may have a problem, but uncertainty is expressed in the note. Possible takes precedence over absent, so terms like “probably not” or “unlikely” categorize problems as being possible just as “probably” and “likely” do.\nHypothetical: medical problems that the note asserts the patient may develop.\nAssociated_with_someone_else: the mention of the medical problem is associated with someone who is not the patient. \n\nPlease write your instruction in such a way that the model will include one of "Present", "Conditional", "Absent", "Possible", "Hypothetical", or "Associated_with_someone_else" in the response. Don't simply copy and paste the provided label descriptions., dtype: float64
#
# Processing column 'Smoker Classification
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a patient discharge note, your aim is to have the model classify the patient's smoking status into one of five categories: Past Smoker, Current Smoker, Smoker, Non-Smoker, and Unknown. Here is the detailed definition of the categories:
#
# Past Smoker: a patient whose discharge note asserts explicitly that the patient was a smoker one year or more ago but who has not smoked for at least one year.
# Current Smoker: a patient whose discharge note asserts explicitly that the patient was a smoker within the past year.
# Smoker: a patient who is either a Current or a Past Smoker but whose medical record does not provide enough information to classify the patient as either.
# Non-Smoker: a patient whose discharge note indicates this person has never smoked.
# Unknown: a patient whose discharge note does not mention anything about smoking.
# Please write your instruction in such a way that the model will include one of "Past Smoker", "Current Smoker", "Smoker", "Non-Smoker", or "Unknown" in the response. Don't simply copy and paste the provided label descriptions. '
# Readability scores for column 'Smoker Classification
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a patient discharge note, your aim is to have the model classify the patient's smoking status into one of five categories: Past Smoker, Current Smoker, Smoker, Non-Smoker, and Unknown. Here is the detailed definition of the categories:
#
# Past Smoker: a patient whose discharge note asserts explicitly that the patient was a smoker one year or more ago but who has not smoked for at least one year.
# Current Smoker: a patient whose discharge note asserts explicitly that the patient was a smoker within the past year.
# Smoker: a patient who is either a Current or a Past Smoker but whose medical record does not provide enough information to classify the patient as either.
# Non-Smoker: a patient whose discharge note indicates this person has never smoked.
# Unknown: a patient whose discharge note does not mention anything about smoking.
# Please write your instruction in such a way that the model will include one of "Past Smoker", "Current Smoker", "Smoker", "Non-Smoker", or "Unknown" in the response. Don't simply copy and paste the provided label descriptions. ':
# 0      9.05
# 1     26.14
# 2     50.87
# 3     64.41
# 4     62.38
# 5     55.58
# 6     53.00
# 7     25.63
# 8     65.56
# 9     68.91
# 10    28.17
# 11    39.00
# Name: Smoker Classification \nInput: the discharge note of a single patient (assume the notes are given above the instruction.)\nGiven a patient discharge note, your aim is to have the model classify the patient's smoking status into one of five categories: Past Smoker, Current Smoker, Smoker, Non-Smoker, and Unknown. Here is the detailed definition of the categories:\n\nPast Smoker: a patient whose discharge note asserts explicitly that the patient was a smoker one year or more ago but who has not smoked for at least one year.\nCurrent Smoker: a patient whose discharge note asserts explicitly that the patient was a smoker within the past year.\nSmoker: a patient who is either a Current or a Past Smoker but whose medical record does not provide enough information to classify the patient as either.\nNon-Smoker: a patient whose discharge note indicates this person has never smoked.\nUnknown: a patient whose discharge note does not mention anything about smoking.\nPlease write your instruction in such a way that the model will include one of "Past Smoker", "Current Smoker", "Smoker", "Non-Smoker", or "Unknown" in the response. Don't simply copy and paste the provided label descriptions. , dtype: float64
#
# Processing column 'Relation Drug Classification
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a patient discharge note, a drug mentioned in the note that causes an adverse drug event, and another piece of textual information, your aim is to have the model classify the relation between the drug and this information as one of the: ADE-Drug, Dosage-Drug, Duration-Drug, Form-Drug, Frequency-Drug, Reason-Drug, Route-Drug, Strength-Drug, and N/A. In your instruction, refer to the drug mentioned using the placeholder '{drug}' and refer to the relevant information using the placeholder '{textual_information}'.
#
# Here is the detailed definition of the categories:
#
# ADE-Drug: the information is about the adverse drug
# event (ADE) that the drug caused
#
# Dosage-Drug: the information is about the dosage
# of the drug usage.
#
# Duration-Drug: the information is about the duration of
# the drug usage.
#
# Form-Drug: the information is about the form of intake
# of the drug.
#
# Frequency-Drug: the information is about the frequency
# of the drug usage.
#
# Reason-Drug: the information is about the reason for the
# prescription of the drug.
#
# Route-Drug: the information is about the route of the
# drug usage.
#
# Strength-Drug: the information is about the strength of
# the drug usage.
#
# N/A: the information is not related with the drug.
# Please write your instruction in such a way that the model will include one of "ADE-Drug", "Dosage-Drug", "Duration-Drug", "Form-Drug", "Frequency-Drug", "Reason-Drug", "Route-Drug", "Strength-Drug", or "N/A" in the response.
# '
# Readability scores for column 'Relation Drug Classification
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a patient discharge note, a drug mentioned in the note that causes an adverse drug event, and another piece of textual information, your aim is to have the model classify the relation between the drug and this information as one of the: ADE-Drug, Dosage-Drug, Duration-Drug, Form-Drug, Frequency-Drug, Reason-Drug, Route-Drug, Strength-Drug, and N/A. In your instruction, refer to the drug mentioned using the placeholder '{drug}' and refer to the relevant information using the placeholder '{textual_information}'.
#
# Here is the detailed definition of the categories:
#
# ADE-Drug: the information is about the adverse drug
# event (ADE) that the drug caused
#
# Dosage-Drug: the information is about the dosage
# of the drug usage.
#
# Duration-Drug: the information is about the duration of
# the drug usage.
#
# Form-Drug: the information is about the form of intake
# of the drug.
#
# Frequency-Drug: the information is about the frequency
# of the drug usage.
#
# Reason-Drug: the information is about the reason for the
# prescription of the drug.
#
# Route-Drug: the information is about the route of the
# drug usage.
#
# Strength-Drug: the information is about the strength of
# the drug usage.
#
# N/A: the information is not related with the drug.
# Please write your instruction in such a way that the model will include one of "ADE-Drug", "Dosage-Drug", "Duration-Drug", "Form-Drug", "Frequency-Drug", "Reason-Drug", "Route-Drug", "Strength-Drug", or "N/A" in the response.
# ':
# 0    -75.71
# 1    -25.30
# 2     55.34
# 3     43.19
# 4     56.35
# 5     53.92
# 6      8.21
# 7     47.59
# 8     39.00
# 9     34.52
# 10     4.49
# 11    12.94
# Name: Relation Drug Classification\nInput: the discharge note of a single patient (assume the notes are given above the instruction.)\nGiven a patient discharge note, a drug mentioned in the note that causes an adverse drug event, and another piece of textual information, your aim is to have the model classify the relation between the drug and this information as one of the: ADE-Drug, Dosage-Drug, Duration-Drug, Form-Drug, Frequency-Drug, Reason-Drug, Route-Drug, Strength-Drug, and N/A. In your instruction, refer to the drug mentioned using the placeholder '{drug}' and refer to the relevant information using the placeholder '{textual_information}'. \n\nHere is the detailed definition of the categories:\n\nADE-Drug: the information is about the adverse drug \nevent (ADE) that the drug caused\n\nDosage-Drug: the information is about the dosage \nof the drug usage.\n\nDuration-Drug: the information is about the duration of \nthe drug usage.\n\nForm-Drug: the information is about the form of intake \nof the drug.\n\nFrequency-Drug: the information is about the frequency \nof the drug usage.\n\nReason-Drug: the information is about the reason for the \nprescription of the drug.\n\nRoute-Drug: the information is about the route of the \ndrug usage.\n\nStrength-Drug: the information is about the strength of \nthe drug usage.\n\nN/A: the information is not related with the drug.\nPlease write your instruction in such a way that the model will include one of "ADE-Drug", "Dosage-Drug", "Duration-Drug", "Form-Drug", "Frequency-Drug", "Reason-Drug", "Route-Drug", "Strength-Drug", or "N/A" in the response.\n, dtype: float64
#
# Processing column 'Temporal Relations Classification
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a discharge summary note of a patient and two events or temporal expressions, your aim is to classify the temporal relations between them as one of: Before, After, Simultaneous, Overlap, Begun_by, Ended_by, During, and Before_overlap. In your instruction, refer to the two events/temporal expressions as '{e1}' and '{e2}'
# Here is the detailed definition of the associated attribute, described by an example:
#
# Before: The patient was given stress dose steroids prior to his surgery. ([stress dose steroids] BEFORE [his surgery])
#
# After: Before admission, he had another serious concussion. ([admission] AFTER [another serious concussion])
#
# Simultaneous: The patient’s serum creatinine on discharge date, 2012-05-06, was 1.9. ([discharge date] SIMULTANEOUS [2012-05-06])
#
# Overlap: She denies any fevers or chills. ([fevers] OVERLAP [chills])
#
# Begun_by: On postoperative day No 1, he was started on Percocet. ([Percocet] BEGUN_BY [postoperative day No 1])
#
# Ended_by: His nasogastric tube was discontinued on 05-26-98. ([His nasogastric] ENDED_BY [05-26-98])
#
# During: His preoperative workup was completed and included a normal white count ([a normal white count] DURING [His preoperative workup])
#
# Before_overlap: The patient had an undocumented history of possible atrial fibrillation prior to admission. ([possible atrial fibrillation] BEFORE_OVERLAP [admission])
# Please write your instruction in such a way that the model will include one of "Before", "After", "Simultaneous", "Overlap", "Begun_by", "Ended_by", "During", or "Before_overlap" in the response.'
# Readability scores for column 'Temporal Relations Classification
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a discharge summary note of a patient and two events or temporal expressions, your aim is to classify the temporal relations between them as one of: Before, After, Simultaneous, Overlap, Begun_by, Ended_by, During, and Before_overlap. In your instruction, refer to the two events/temporal expressions as '{e1}' and '{e2}'
# Here is the detailed definition of the associated attribute, described by an example:
#
# Before: The patient was given stress dose steroids prior to his surgery. ([stress dose steroids] BEFORE [his surgery])
#
# After: Before admission, he had another serious concussion. ([admission] AFTER [another serious concussion])
#
# Simultaneous: The patient’s serum creatinine on discharge date, 2012-05-06, was 1.9. ([discharge date] SIMULTANEOUS [2012-05-06])
#
# Overlap: She denies any fevers or chills. ([fevers] OVERLAP [chills])
#
# Begun_by: On postoperative day No 1, he was started on Percocet. ([Percocet] BEGUN_BY [postoperative day No 1])
#
# Ended_by: His nasogastric tube was discontinued on 05-26-98. ([His nasogastric] ENDED_BY [05-26-98])
#
# During: His preoperative workup was completed and included a normal white count ([a normal white count] DURING [His preoperative workup])
#
# Before_overlap: The patient had an undocumented history of possible atrial fibrillation prior to admission. ([possible atrial fibrillation] BEFORE_OVERLAP [admission])
# Please write your instruction in such a way that the model will include one of "Before", "After", "Simultaneous", "Overlap", "Begun_by", "Ended_by", "During", or "Before_overlap" in the response.':
# 0    -30.03
# 1    -55.75
# 2     18.86
# 3     61.02
# 4     70.29
# 5     56.96
# 6     64.81
# 7     25.29
# 8     38.69
# 9     69.48
# 10    33.75
# 11    31.17
# Name: Temporal Relations Classification \nInput: the discharge note of a single patient (assume the notes are given above the instruction.)\nGiven a discharge summary note of a patient and two events or temporal expressions, your aim is to classify the temporal relations between them as one of: Before, After, Simultaneous, Overlap, Begun_by, Ended_by, During, and Before_overlap. In your instruction, refer to the two events/temporal expressions as '{e1}' and '{e2}'\nHere is the detailed definition of the associated attribute, described by an example:\n\nBefore: The patient was given stress dose steroids prior to his surgery. ([stress dose steroids] BEFORE [his surgery])\n\nAfter: Before admission, he had another serious concussion. ([admission] AFTER [another serious concussion])\n\nSimultaneous: The patient’s serum creatinine on discharge date, 2012-05-06, was 1.9. ([discharge date] SIMULTANEOUS [2012-05-06])\n\nOverlap: She denies any fevers or chills. ([fevers] OVERLAP [chills])\n\nBegun_by: On postoperative day No 1, he was started on Percocet. ([Percocet] BEGUN_BY [postoperative day No 1])\n\nEnded_by: His nasogastric tube was discontinued on 05-26-98. ([His nasogastric] ENDED_BY [05-26-98])\n\nDuring: His preoperative workup was completed and included a normal white count ([a normal white count] DURING [His preoperative workup])\n\nBefore_overlap: The patient had an undocumented history of possible atrial fibrillation prior to admission. ([possible atrial fibrillation] BEFORE_OVERLAP [admission])\nPlease write your instruction in such a way that the model will include one of "Before", "After", "Simultaneous", "Overlap", "Begun_by", "Ended_by", "During", or "Before_overlap" in the response., dtype: float64
#
# Processing column 'Coreference Resolution GT
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
#
# Given a discharge summary note of a patient and a entity (textual representation of an entity in the note, like a medicine), your aim is to have the model find all the other texts in the note that represent the same entity. In your instruction, refer to the given entity using the placeholder '{entity}'.
# For instance, if the report says “Patient recorded as having No Known Allergies to Drugs…Mr. Smith is a 63-year-old male with worsening anginal symptoms who underwent catheterization that showed severe three-vessel disease.”, then given the query mention of ‘patient’, the model should extract the following references: “mr. smith, who,…”.
# Please write your instruction in such a way that the model will output a list of text spans/snippets.'
# Readability scores for column 'Coreference Resolution GT
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
#
# Given a discharge summary note of a patient and a entity (textual representation of an entity in the note, like a medicine), your aim is to have the model find all the other texts in the note that represent the same entity. In your instruction, refer to the given entity using the placeholder '{entity}'.
# For instance, if the report says “Patient recorded as having No Known Allergies to Drugs…Mr. Smith is a 63-year-old male with worsening anginal symptoms who underwent catheterization that showed severe three-vessel disease.”, then given the query mention of ‘patient’, the model should extract the following references: “mr. smith, who,…”.
# Please write your instruction in such a way that the model will output a list of text spans/snippets.':
# 0     67.08
# 1     24.11
# 2     55.74
# 3     45.76
# 4     65.73
# 5     40.04
# 6     81.63
# 7     64.71
# 8     76.56
# 9     58.58
# 10    49.15
# 11    76.22
# Name: Coreference Resolution GT\nInput: the discharge note of a single patient (assume the notes are given above the instruction.)\n\nGiven a discharge summary note of a patient and a entity (textual representation of an entity in the note, like a medicine), your aim is to have the model find all the other texts in the note that represent the same entity. In your instruction, refer to the given entity using the placeholder '{entity}'.\nFor instance, if the report says “Patient recorded as having No Known Allergies to Drugs…Mr. Smith is a 63-year-old male with worsening anginal symptoms who underwent catheterization that showed severe three-vessel disease.”, then given the query mention of ‘patient’, the model should extract the following references: “mr. smith, who,…”.\nPlease write your instruction in such a way that the model will output a list of text spans/snippets., dtype: float64
#
# Processing column 'Medication Extraction
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a discharge summary note of a patient, your aim is to have the model extract all the medications in the discharge note.
#
# For instance, for the phrase ‘ADMISSION MEDICATIONS: Colace 100 mg b.i.d. , insulin Lente 12 units subcu q p.m.’ in the discharge note, the model should extract ‘colace, insulin lente’.
#
# Note: medications include names, brand names, generics, and collective names of prescription substances, over-the-counter medications, and other biological substances for which the patient is the experiencer.
# Please write your instruction in such a way that the model will output a list of text spans/snippets.'
# Readability scores for column 'Medication Extraction
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a discharge summary note of a patient, your aim is to have the model extract all the medications in the discharge note.
#
# For instance, for the phrase ‘ADMISSION MEDICATIONS: Colace 100 mg b.i.d. , insulin Lente 12 units subcu q p.m.’ in the discharge note, the model should extract ‘colace, insulin lente’.
#
# Note: medications include names, brand names, generics, and collective names of prescription substances, over-the-counter medications, and other biological substances for which the patient is the experiencer.
# Please write your instruction in such a way that the model will output a list of text spans/snippets.':
# 0     18.69
# 1     32.06
# 2     55.24
# 3     57.27
# 4     34.26
# 5     29.86
# 6     63.70
# 7     70.80
# 8     32.73
# 9     50.87
# 10    24.27
# 11    44.75
# Name: Medication Extraction\nInput: the discharge note of a single patient (assume the notes are given above the instruction.)\nGiven a discharge summary note of a patient, your aim is to have the model extract all the medications in the discharge note.\n\nFor instance, for the phrase ‘ADMISSION MEDICATIONS: Colace 100 mg b.i.d. , insulin Lente 12 units subcu q p.m.’ in the discharge note, the model should extract ‘colace, insulin lente’.\n\nNote: medications include names, brand names, generics, and collective names of prescription substances, over-the-counter medications, and other biological substances for which the patient is the experiencer.\nPlease write your instruction in such a way that the model will output a list of text spans/snippets., dtype: float64
#
# Processing column 'Medication Dosage Extraction
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a discharge summary note of a patient and a queried medication, your aim is to have the model extract the dosage of that medication - the amount of a medication used in each administration - in the discharge note. In your instruction, refer to the queried medication as '{medication}'.
#
# For instance, for the phrase ‘ADMISSION MEDICATIONS: Colace 100 mg b.i.d. , insulin Lente 12 units subcu q p.m.’ in the discharge note and the queried medication ‘insulin lente’, the model should extract ‘12 units’.
# Please write your instruction in such a way that the model will output a text span/snippet.'
# Readability scores for column 'Medication Dosage Extraction
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
# Given a discharge summary note of a patient and a queried medication, your aim is to have the model extract the dosage of that medication - the amount of a medication used in each administration - in the discharge note. In your instruction, refer to the queried medication as '{medication}'.
#
# For instance, for the phrase ‘ADMISSION MEDICATIONS: Colace 100 mg b.i.d. , insulin Lente 12 units subcu q p.m.’ in the discharge note and the queried medication ‘insulin lente’, the model should extract ‘12 units’.
# Please write your instruction in such a way that the model will output a text span/snippet.':
# 0     65.73
# 1     40.35
# 2     56.76
# 3     31.89
# 4     45.42
# 5     31.58
# 6     48.81
# 7     42.72
# 8     59.98
# 9     58.99
# 10    37.30
# 11    68.77
# ...
#
# Processing column 'Drug Dosage Extraction
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
#
# Given a discharge summary note of a patient, your aim is to have the model extract all the text mentioning the dosage information regarding the drug that causes adverse drug events mentioned in the note.
#
# For instance, in the lines "Medications on Admission:
# 1. Lorazepam 0.5 mg Tablet Sig: One (1) Tablet PO Q4-6H
#  (every 4to 6 hours) as needed." of a discharge note,
# "One (1)" is a dosage information.
#
# Please write your instruction in such a way that the model will output a list of text spans/snippets. '
# Readability scores for column 'Drug Dosage Extraction
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
#
# Given a discharge summary note of a patient, your aim is to have the model extract all the text mentioning the dosage information regarding the drug that causes adverse drug events mentioned in the note.
#
# For instance, in the lines "Medications on Admission:
# 1. Lorazepam 0.5 mg Tablet Sig: One (1) Tablet PO Q4-6H
#  (every 4to 6 hours) as needed." of a discharge note,
# "One (1)" is a dosage information.
#
# Please write your instruction in such a way that the model will output a list of text spans/snippets. ':
# 0     46.10
# 1     56.93
# 2     45.09
# 3     53.21
# 4     45.76
# 5     56.08
# 6     35.95
# 7     65.73
# 8     64.04
# 9     72.36
# 10    59.13
# 11    71.14
# Name: Drug Dosage Extraction\nInput: the discharge note of a single patient (assume the notes are given above the instruction.)\n\nGiven a discharge summary note of a patient, your aim is to have the model extract all the text mentioning the dosage information regarding the drug that causes adverse drug events mentioned in the note.\n\nFor instance, in the lines "Medications on Admission:\n1. Lorazepam 0.5 mg Tablet Sig: One (1) Tablet PO Q4-6H\n (every 4to 6 hours) as needed." of a discharge note, \n"One (1)" is a dosage information.\n\nPlease write your instruction in such a way that the model will output a list of text spans/snippets. , dtype: float64
#
# Processing column 'Drug Extraction
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
#
# Given a discharge summary note of a patient, your aim is to have the model extract the text mentioning the name of the drugs mentioned in the note that result in adverse drug events.
#
# For instance, in the lines "Discharge Medication: 1. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)." of a discharge note, the text "Docusate Sodium" is a drug that result in adverse drug events.
#
# Please write your instruction in such a way that the model will output a list of text spans/snippets. '
# Readability scores for column 'Drug Extraction
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
#
# Given a discharge summary note of a patient, your aim is to have the model extract the text mentioning the name of the drugs mentioned in the note that result in adverse drug events.
#
# For instance, in the lines "Discharge Medication: 1. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)." of a discharge note, the text "Docusate Sodium" is a drug that result in adverse drug events.
#
# Please write your instruction in such a way that the model will output a list of text spans/snippets. ':
# 0     55.58
# 1     54.22
# 2     76.56
# 3     64.04
# 4     60.14
# 5     80.62
# 6     47.79
# 7     74.19
# 8     91.45
# 9     78.59
# 10    69.11
# 11    79.60
# Name: Drug Extraction \nInput: the discharge note of a single patient (assume the notes are given above the instruction.)\n\nGiven a discharge summary note of a patient, your aim is to have the model extract the text mentioning the name of the drugs mentioned in the note that result in adverse drug events.\n\nFor instance, in the lines "Discharge Medication: 1. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)." of a discharge note, the text "Docusate Sodium" is a drug that result in adverse drug events.\n\nPlease write your instruction in such a way that the model will output a list of text spans/snippets. , dtype: float64
#
# Processing column 'Drug Usage Duration Extraction
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
#
# Given a discharge summary note of a patient, your aim is to have the model extract all the text referencing the duration of the drug usage related to the adverse drug events mentioned in the note.
#
# For instance, in the lines "Discharge Medications: 1. Bactrim DS 160-800 mg Tablet Sig: Two (2) Tablet PO twice a day for 1 weeks." of a discharge note, the text "for 1 weeks" is the duration information.
#
# Please write your instruction in such a way that the model will output a list of text spans/snippets. '
# Readability scores for column 'Drug Usage Duration Extraction
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
#
# Given a discharge summary note of a patient, your aim is to have the model extract all the text referencing the duration of the drug usage related to the adverse drug events mentioned in the note.
#
# For instance, in the lines "Discharge Medications: 1. Bactrim DS 160-800 mg Tablet Sig: Two (2) Tablet PO twice a day for 1 weeks." of a discharge note, the text "for 1 weeks" is the duration information.
#
# Please write your instruction in such a way that the model will output a list of text spans/snippets. ':
# 0     56.55
# 1     53.21
# 2     62.01
# 3     59.98
# 4     52.19
# 5     72.66
# 6     48.13
# 7     65.73
# 8     48.47
# 9     69.11
# 10    53.21
# 11    71.14
# Name: Drug Usage Duration Extraction \nInput: the discharge note of a single patient (assume the notes are given above the instruction.)\n\nGiven a discharge summary note of a patient, your aim is to have the model extract all the text referencing the duration of the drug usage related to the adverse drug events mentioned in the note.\n\nFor instance, in the lines "Discharge Medications: 1. Bactrim DS 160-800 mg Tablet Sig: Two (2) Tablet PO twice a day for 1 weeks." of a discharge note, the text "for 1 weeks" is the duration information.\n\nPlease write your instruction in such a way that the model will output a list of text spans/snippets. , dtype: float64
#
# Processing column 'Drug Intake Form Extraction
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
#
# Given a discharge summary note of a patient, your aim is to have the model extract all text referencing the intake form of the drugs mentioned in the note that are related to the adverse drug events.
#
# For instance, in the lines "3. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day). Disp:*60 Capsule(s)* Refills:*2*" of a discharge note, the text "Capsule" is the intake form of a drug usage.
#
# Please write your instruction in such a way that the model will output a list of text spans/snippets. '
# Readability scores for column 'Drug Intake Form Extraction
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
#
# Given a discharge summary note of a patient, your aim is to have the model extract all text referencing the intake form of the drugs mentioned in the note that are related to the adverse drug events.
#
# For instance, in the lines "3. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day). Disp:*60 Capsule(s)* Refills:*2*" of a discharge note, the text "Capsule" is the intake form of a drug usage.
#
# Please write your instruction in such a way that the model will output a list of text spans/snippets. ':
# 0     56.59
# 1     62.68
# 2     48.47
# 3     53.55
# 4     60.14
# 5     70.13
# 6     56.59
# 7     72.66
# 8     68.44
# 9     66.78
# 10    54.52
# 11    79.09
# Name: Drug Intake Form Extraction\nInput: the discharge note of a single patient (assume the notes are given above the instruction.)\n\nGiven a discharge summary note of a patient, your aim is to have the model extract all text referencing the intake form of the drugs mentioned in the note that are related to the adverse drug events.\n\nFor instance, in the lines "3. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day). Disp:*60 Capsule(s)* Refills:*2*" of a discharge note, the text "Capsule" is the intake form of a drug usage.\n\nPlease write your instruction in such a way that the model will output a list of text spans/snippets. , dtype: float64
#
# Processing column 'Drug Usage Frequency Extraction
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
#
# Given a discharge summary note of a patient, your aim is to have the model extract the information on the frequency of usage for the drugs mentioned in the note that are related to the adverse drug events.
#
# For instance, in the lines "Discharge Medications: 1. Bactrim DS 160-800 mg Tablet Sig: Two (2) Tablet PO twice a day for 1 weeks. Disp:*28 Tablet(s)* Refills:*0* 2. Mineral Oil     Oil Sig: 2.5 MLs PO DAILY (Daily)." of a discharge note, the text "Daily" is one frequency information.
#
# Please write your instruction in such a way that the model will output a list of text spans/snippets. '
# Readability scores for column 'Drug Usage Frequency Extraction
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
#
# Given a discharge summary note of a patient, your aim is to have the model extract the information on the frequency of usage for the drugs mentioned in the note that are related to the adverse drug events.
#
# For instance, in the lines "Discharge Medications: 1. Bactrim DS 160-800 mg Tablet Sig: Two (2) Tablet PO twice a day for 1 weeks. Disp:*28 Tablet(s)* Refills:*0* 2. Mineral Oil     Oil Sig: 2.5 MLs PO DAILY (Daily)." of a discharge note, the text "Daily" is one frequency information.
#
# Please write your instruction in such a way that the model will output a list of text spans/snippets. ':
# 0     48.13
# 1     52.19
# 2     69.11
# 3     60.99
# 4     51.18
# 5     67.59
# 6     37.30
# 7     71.65
# 8     53.89
# 9     68.60
# 10    54.93
# 11    71.14
# Name: Drug Usage Frequency Extraction\nInput: the discharge note of a single patient (assume the notes are given above the instruction.)\n\nGiven a discharge summary note of a patient, your aim is to have the model extract the information on the frequency of usage for the drugs mentioned in the note that are related to the adverse drug events.\n\nFor instance, in the lines "Discharge Medications: 1. Bactrim DS 160-800 mg Tablet Sig: Two (2) Tablet PO twice a day for 1 weeks. Disp:*28 Tablet(s)* Refills:*0* 2. Mineral Oil     Oil Sig: 2.5 MLs PO DAILY (Daily)." of a discharge note, the text "Daily" is one frequency information.\n\nPlease write your instruction in such a way that the model will output a list of text spans/snippets. , dtype: float64
#
# Processing column 'Drug Reason Extraction
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
#
# Given a discharge summary note of a patient, your aim is to have the model extract all text referencing the reason(s) for prescribing the drugs related to the adverse drug events mentioned in the note.
#
# For instance, in the lines "# Rhythm: Patient was in atrial fibrillation, and not anticoagulated. She was not on aspirin or coumadin because of a previous GI bleed.  Metoprolol was held given her hypotension." of a discharge note, the text "atrial fibrillation" is the an information on the reason for prescribing the drug.
#
# Please write your instruction in such a way that the model will output a list of text spans/snippets. '
# Readability scores for column 'Drug Reason Extraction
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
#
# Given a discharge summary note of a patient, your aim is to have the model extract all text referencing the reason(s) for prescribing the drugs related to the adverse drug events mentioned in the note.
#
# For instance, in the lines "# Rhythm: Patient was in atrial fibrillation, and not anticoagulated. She was not on aspirin or coumadin because of a previous GI bleed.  Metoprolol was held given her hypotension." of a discharge note, the text "atrial fibrillation" is the an information on the reason for prescribing the drug.
#
# Please write your instruction in such a way that the model will output a list of text spans/snippets. ':
# 0     48.64
# 1     45.25
# 2     42.04
# 3     60.99
# 4     48.64
# 5     68.60
# 6     58.62
# 7     67.76
# 8     68.44
# 9     55.27
# 10    37.30
# 11    79.09
# Name: Drug Reason Extraction\nInput: the discharge note of a single patient (assume the notes are given above the instruction.)\n\nGiven a discharge summary note of a patient, your aim is to have the model extract all text referencing the reason(s) for prescribing the drugs related to the adverse drug events mentioned in the note.\n\nFor instance, in the lines "# Rhythm: Patient was in atrial fibrillation, and not anticoagulated. She was not on aspirin or coumadin because of a previous GI bleed.  Metoprolol was held given her hypotension." of a discharge note, the text "atrial fibrillation" is the an information on the reason for prescribing the drug.\n\nPlease write your instruction in such a way that the model will output a list of text spans/snippets. , dtype: float64
#
# Processing column 'Drug Strength Extraction
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
#
# Given a discharge summary note of a patient, your aim is to have the model extract all text referencing the strength (quantity) of the drugs related to the adverse drug events mentioned in the note.
#
# For instance, in the line "Mirtazapine 15 mg PO QHS" of a discharge note, the text "15 mg" is the strength (quantity) information.
#
# Please write your instruction in such a way that the model will output a list of text spans/snippets. '
# Readability scores for column 'Drug Strength Extraction
# Input: the discharge note of a single patient (assume the notes are given above the instruction.)
#
# Given a discharge summary note of a patient, your aim is to have the model extract all text referencing the strength (quantity) of the drugs related to the adverse drug events mentioned in the note.
#
# For instance, in the line "Mirtazapine 15 mg PO QHS" of a discharge note, the text "15 mg" is the strength (quantity) information.
#
# Please write your instruction in such a way that the model will output a list of text spans/snippets. ':
# 0     47.62
# 1     53.21
# 2     51.52
# 3     56.59
# 4     57.10
# 5     64.71
# 6     57.61
# 7     61.67
# 8     71.48
# 9     75.74
# 10    54.73
# 11    79.60
# Name: Drug Strength Extraction\nInput: the discharge note of a single patient (assume the notes are given above the instruction.)\n\nGiven a discharge summary note of a patient, your aim is to have the model extract all text referencing the strength (quantity) of the drugs related to the adverse drug events mentioned in the note.\n\nFor instance, in the line "Mirtazapine 15 mg PO QHS" of a discharge note, the text "15 mg" is the strength (quantity) information.\n\nPlease write your instruction in such a way that the model will output a list of text spans/snippets. , dtype: float64

# %% [markdown]
# ### Plots for logit based

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import f1_score, precision_score, recall_score
import numpy as np
from sklearn.metrics import roc_auc_score
import seaborn as sns

import numpy as np

df_results = pd.read_csv("/work/frink/private_datasets/final_classification.csv")


def convert_to_float_list(string_list):
    return [float(x) for x in string_list.strip("[]").split(", ")]


# Apply the function to the 'probabilities' column
df_results["probabilities"] = df_results["probabilities"].apply(convert_to_float_list)
df_results["positive_probabilities"] = [p[1] for p in df_results["probabilities"]]
all_datasets = df_results["dataset"].unique()
all_models = df_results["model"].unique()
all_annotators = df_results["annotator"].unique()
df_results = df_results.sort_values(by=["dataset", "model", "annotator"])
all_auroc = []

df_list = []

for dataset in all_datasets:
    for model in all_models:
        for annotator in all_annotators:
            df = df_results[
                (df_results["dataset"] == dataset)
                & (df_results["model"] == model)
                & (df_results["annotator"] == annotator)
            ].copy()
            labels = df["gold_class"].unique()
            auroc = roc_auc_score(df["gold_class"], df["positive_probabilities"])
            df["auroc"] = auroc
            df_list.append(df)

df_results = pd.concat(df_list)
df_results = df_results.drop(["instance", "probabilities"], axis=1)

df_results_grouped = (
    df_results.groupby(["task_type", "dataset", "model", "annotator"])
    .mean()
    .reset_index()
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 34
#      29 for model in all_models:
#      30     for annotator in all_annotators:
#      31         df = df_results[
#      32             (df_results["dataset"] == dataset)
#      33             & (df_results["model"] == model)
# ---> 34             & (df_results["annotator"] == annotator)
#      35         ].copy()
#      36         labels = df["gold_class"].unique()
#      37         auroc = roc_auc_score(df["gold_class"], df["positive_probabilities"])
#
# File ~/.conda/envs/robust/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/.conda/envs/robust/lib/python3.11/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/.conda/envs/robust/lib/python3.11/site-packages/pandas/core/series.py:6110, in Series._cmp_method(self, other, op)
#    6107 lvalues = self._values
#    6108 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6110 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6112 return self._construct_result(res_values, name=res_name)
#
# File ~/.conda/envs/robust/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/.conda/envs/robust/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
def get_results_stacked(df_results_grouped, how="max"):
    datasets = df_results_grouped["dataset"].unique()
    models = df_results_grouped["model"].unique()
    if how == "max":
        df_results_grouped_max = (
            df_results_grouped[["dataset", "model", "auroc"]]
            .groupby(["dataset", "model"])
            .max()
            .reset_index()
        )
    elif how == "min":
        df_results_grouped_max = (
            df_results_grouped[["dataset", "model", "auroc"]]
            .groupby(["dataset", "model"])
            .min()
            .reset_index()
        )
    else:
        df_results_grouped_max = (
            df_results_grouped[["dataset", "model", "auroc"]]
            .groupby(["dataset", "model"])
            .mean()
            .reset_index()
        )

    df_results_grouped_max = (
        df_results_grouped_max[["model", "auroc"]].groupby("model").mean()
    )

    return df_results_grouped_max

# %%
df_results_grouped = df_results_grouped[["dataset", "model", "annotator", "auroc"]]

annotators = df_results_grouped["annotator"].unique()
datasets = df_results_grouped["dataset"].unique()
models = df_results_grouped["model"].unique()

# for each model,dataset pair, get the annotator with the highest f1

# %%
df_results_grouped_max_cnt = get_results_stacked(df_results_grouped, "max")
df_results_grouped_min_cnt = get_results_stacked(df_results_grouped, "min")
df_results_grouped_mean_cnt = get_results_stacked(df_results_grouped, "mean")
df_results_grouped_max_cnt["type"] = "Best"
df_results_grouped_min_cnt["type"] = "Worst"
df_results_grouped_mean_cnt["type"] = "Median"

# stack

results = pd.concat(
    [
        df_results_grouped_max_cnt,
        df_results_grouped_mean_cnt,
        df_results_grouped_min_cnt,
    ]
)


ORDER_MAP = {
    "Llama-2-7b-chat-hf": 2,
    "Llama-2-13b-chat": 1,
    "alpaca-7b": 3,
    "mistral-7b": 0,
    "asclepius": 6,
    "clinical-camel-7b": 5,
    "medalpaca-7b": 7,
}

results["order"] = results.index.map(ORDER_MAP)
results = results.sort_values(by=["order", "type"])

# %%
colors
# Out:
# [(0.33725490196078434, 0.45647058823529396, 0.6509803921568628),
#  (0.8121568627450981, 0.5329411764705883, 0.3760784313725489),
#  (0.36588235294117644, 0.6262745098039216, 0.4254901960784314),
#  (0.7223529411764706, 0.35215686274509816, 0.36470588235294116),
#  (0.519607843137255, 0.47254901960784323, 0.6764705882352939),
#  (0.556470588235294, 0.4717647058823529, 0.39647058823529413),
#  (0.823921568627451, 0.5760784313725489, 0.7517647058823529),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.7654901960784315, 0.7058823529411765, 0.4894117647058822),
#  (0.43333333333333335, 0.6874509803921568, 0.7627450980392156)]

# %%
MODEL_MAP = {
    "mistral-7b": "Mistral (7b)",
    "Llama-2-7b-chat-hf": "Llama-2 (7b)",
    "asclepius": "Asclepius (7b)",
    "Llama-2-13b-chat": "Llama-2 (13b)",
    "clinical-camel-7b": "Clin-Camel (13b)",
    "alpaca-7b": "Alpaca (7b)",
    "medalpaca-7b": "MedAlpaca (7b)",
}
models_a = ["Mistral (7b)", "Llama-2 (7b)", "Llama-2 (13b)", "Alpaca (7b)"]
models_b = ["Asclepius (7b)", "Clin-Camel (13b)", "MedAlpaca (7b)"]
results = results.reset_index()

results["model"] = results.model.map(MODEL_MAP)
results.columns = ["Model", "AUROC", "Prompt", "order"]

# %% [markdown]
# # EXTRACTION

# %%
df_results_grouped_extraction = pd.read_csv(
    "/work/frink/private_datasets/extraction.csv"
).drop(columns=["Unnamed: 0"])
df_results_grouped_extraction = df_results_grouped_extraction.rename(
    columns={"f1_score": "F1"}
)
df_results_grouped = pd.concat(
    [df_results_grouped, df_results_grouped_extraction], axis=0
)

df_results_grouped_extraction["model"].unique()
# Out:
# array(['Llama-2-7b-chat-hf', 'Llama-2-13b-chat', 'alpaca-7b', 'asclepius',
#        'clinical-camel-7b', 'medalpaca-7b', 'mistral-7b'], dtype=object)

# %%
def get_results_stacked(df_results_grouped, how="max"):
    datasets = df_results_grouped["dataset"].unique()
    models = df_results_grouped["model"].unique()
    if how == "max":
        df_results_grouped_max = (
            df_results_grouped[["dataset", "model", "F1"]]
            .groupby(["dataset", "model"])
            .max()
            .reset_index()
        )
    elif how == "min":
        df_results_grouped_max = (
            df_results_grouped[["dataset", "model", "F1"]]
            .groupby(["dataset", "model"])
            .min()
            .reset_index()
        )
    else:
        df_results_grouped_max = (
            df_results_grouped[["dataset", "model", "F1"]]
            .groupby(["dataset", "model"])
            .mean()
            .reset_index()
        )

    df_results_grouped_max = (
        df_results_grouped_max[["model", "F1"]].groupby("model").mean()
    )

    return df_results_grouped_max

# %%
columns = ["dataset", "model", "annotator", "F1"]

df_results_grouped_extraction = pd.read_csv(
    "/work/frink/private_datasets/extraction.csv"
).drop(columns=["Unnamed: 0"])

df_results_grouped_extraction = df_results_grouped_extraction.rename(
    columns={"f1_score": "F1"}
).reset_index()

df_results_grouped_max_cnt = get_results_stacked(df_results_grouped_extraction, "max")
df_results_grouped_min_cnt = get_results_stacked(df_results_grouped_extraction, "min")
df_results_grouped_mean_cnt = get_results_stacked(df_results_grouped_extraction, "mean")
df_results_grouped_max_cnt["type"] = "Best"
df_results_grouped_min_cnt["type"] = "Worst"
df_results_grouped_mean_cnt["type"] = "Median"
results = [
    df_results_grouped_max_cnt,
    df_results_grouped_mean_cnt,
    df_results_grouped_min_cnt,
]
results = pd.concat(results)
results
# Out:
#                           F1    type
# model
# Llama-2-13b-chat    0.387880    Best
# Llama-2-7b-chat-hf  0.431393    Best
# alpaca-7b           0.230052    Best
# asclepius           0.347388    Best
# clinical-camel-7b   0.414732    Best
# medalpaca-7b        0.344597    Best
# mistral-7b          0.360897    Best
# Llama-2-13b-chat    0.296618  Median
# Llama-2-7b-chat-hf  0.352255  Median
# alpaca-7b           0.134112  Median
# asclepius           0.302531  Median
# clinical-camel-7b   0.269515  Median
# medalpaca-7b        0.265183  Median
# mistral-7b          0.231001  Median
# Llama-2-13b-chat    0.215099   Worst
# Llama-2-7b-chat-hf  0.257234   Worst
# alpaca-7b           0.078620   Worst
# asclepius           0.253291   Worst
# clinical-camel-7b   0.122080   Worst
# medalpaca-7b        0.184390   Worst
# mistral-7b          0.135194   Worst

# %%
results["order"] = results.index.map(ORDER_MAP)
results = results.sort_values(by=["order", "type"])
MODEL_MAP = {
    "Llama-2-7b-chat-hf": "Llama-2 (7b)",
    "asclepius": "Asclepius (7b)",
    "Llama-2-13b-chat": "Llama-2 (13b)",
    "clinical-camel-7b": "Clin-Camel (13b)",
    "alpaca-7b": "Alpaca (7b)",
    "medalpaca-7b": "MedAlpaca (7b)",
    "mistral-7b": "Mistral (7b)",
}
models_a = ["Mistral (7b)", "Llama-2 (7b)", "Llama-2 (13b)", "Alpaca (7b)"]
models_b = ["Asclepius (7b)", "Clin-Camel (13b)", "MedAlpaca (7b)"]
results = results.reset_index()

results["model"] = results.model.map(MODEL_MAP)
results.columns = ["Model", "F1", "Prompt", "order"]
